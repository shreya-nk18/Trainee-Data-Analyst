# %%
a_shreya=1
print("yes")
# Out:
# yes

# %%
_shreya=1
print("no")
# Out:
# no

# %%
9_shre=12
print(9_shre)
# Out:
#   Cell In[6], line 1
#     9_shre=12
#      ^
# SyntaxError: invalid decimal literal

# %%
shre=1
print(shre)
# Out:
# 1

# %%
_=2
print(_)
# Out:
# 2

# %%
9_=0
print(9_)
# Out:
#   Cell In[14], line 1
#     9_=0
#      ^
# SyntaxError: invalid decimal literal

# %%
shre9=12
print(shre9)
# Out:
# 12

# %%
s=10
print(s)
# Out:
# 10

# %%
a="shreya"
type(a)
# Out:
# str

# %%
b=6
type(b)
# Out:
# int

# %%
c=6.7
type(c)
# Out:
# float

# %%
d=True
type(d)
# Out:
# bool

# %%
e=5+4j
type(e)
# Out:
# complex

# %%
x=12
y=5
x+y
# Out:
# 17

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x=10
y=5
x//y
# Out:
# 2

# %%
x=10
y=5
x%y
# Out:
# 0

# %%
x**y
# Out:
# 100000

# %%
5==3
# Out:
# False

# %%
5!=3
# Out:
# True

# %%
5>=6
# Out:
# False

# %%
6<=10
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not False
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
not True
# Out:
# False

# %%
string='hii welcome back'
string=string.upper()
string
# Out:
# 'HII WELCOME BACK'

# %%
string='hii welcome back'
string=string.lower()
string
# Out:
# 'hii welcome back'

# %%
data="apple,banana,grapes"
fruits=data.split(",")
print(fruits)
# Out:
# ['apple', 'banana', 'grapes']
