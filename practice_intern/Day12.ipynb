# %% [markdown]
# # set

# %%
#set is a collection of data type used to store multiple unique values
#set cannot have duplicate values
#create set
s1={1,5,8}
s1
# Out:
# {1, 5, 8}

# %%
s1={10,2,8,10,10,8}
print(s1)
# Out:
# {8, 10, 2}

# %%
#create empty list
s2={}
type(s2)
# Out:
# dict

# %%
s3=set()
type(s3)
# Out:
# set

# %%
s4=set([1,5,3])
s4
type(s4)
# Out:
# set

# %%
s5={10,40,50,20}
s5
# Out:
# {10, 20, 40, 50}

# %%
type(s5)
# Out:
# set

# %%
for e in s5:
    print(e)
# Out:
# 40
# 10
# 50
# 20
