# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\naiks\Downloads\data_cleaning_sample.csv")
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df1=df.dropna()
df1
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %% [markdown]
# # converting the datatypes

# %%
df1["Age"]=df1["Age"].astype(int)
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\227691704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Age"]=df1["Age"].astype(int)
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 280.0+ bytes

# %%
df1["Gender"]=df1["Gender"].astype("category")
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\3904898133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Gender"]=df1["Gender"].astype("category")
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   City       5 non-null      object
#  3   Gender     5 non-null      category
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: category(1), int64(1), object(4)
# memory usage: 369.0+ bytes

# %%
df1["Gender"].cat.codes
# Out:
# 0    0
# 2    1
# 4    1
# 6    0
# 7    0
# dtype: int8

# %%
df1["Join Date"]=pd.to_datetime(df1["Join Date"],format="%d-%m-%Y")
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\4154373017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Join Date"]=pd.to_datetime(df1["Join Date"],format="%d-%m-%Y")

# %%
df1
# Out:
#     Name  Age         City Gender              Email  Join Date
# 0  Alice   25     New York      F  alice@example.com 2021-05-01
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15
# 4  David   22       Mumbai      M  david@example.com 2019-11-12
# 6  Alice   25     New York      F  alice@example.com 2021-05-01
# 7  Alice   25     New York      F  alice@example.com 2021-05-01

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   City       5 non-null      object
#  3   Gender     5 non-null      category
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      datetime64[ns]
# dtypes: category(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 369.0+ bytes

# %% [markdown]
# # Extracting join date to year

# %%
df1["Year"]=df1["Join Date"].dt.year
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\3164802390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Year"]=df1["Join Date"].dt.year
#     Name  Age         City Gender              Email  Join Date  Year
# 0  Alice   25     New York      F  alice@example.com 2021-05-01  2021
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15  2020
# 4  David   22       Mumbai      M  david@example.com 2019-11-12  2019
# 6  Alice   25     New York      F  alice@example.com 2021-05-01  2021
# 7  Alice   25     New York      F  alice@example.com 2021-05-01  2021

# %%
df1["Month"]=df1["Join Date"].dt.month
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\392511580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Month"]=df1["Join Date"].dt.month
#     Name  Age         City Gender              Email  Join Date  Year  Month
# 0  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David   22       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5

# %%
df1["Day"]=df1["Join Date"].dt.day
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\22039300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Day"]=df1["Join Date"].dt.day
#     Name  Age         City Gender              Email  Join Date  Year  Month  \
# 0  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David   22       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
#
#    Day
# 0    1
# 2   15
# 4   12
# 6    1
# 7    1

# %%
df1["Month_Name"]=df1["Join Date"].dt.month_name()
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\546737845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Month_Name"]=df1["Join Date"].dt.month_name()
#     Name  Age         City Gender              Email  Join Date  Year  Month  \
# 0  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David   22       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
#
#    Day Month_Name
# 0    1        May
# 2   15       June
# 4   12   November
# 6    1        May
# ...

# %%
df1["Day_Name"]=df1["Join Date"].dt.day_name()
df1
# Out:
# C:\Users\naiks\AppData\Local\Temp\ipykernel_18744\3285327571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Day_Name"]=df1["Join Date"].dt.day_name()
#     Name  Age         City Gender              Email  Join Date  Year  Month  \
# 0  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David   22       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice   25     New York      F  alice@example.com 2021-05-01  2021      5
#
#    Day Month_Name  Day_Name
# 0    1        May  Saturday
# 2   15       June    Monday
# ...

# %% [markdown]
# # Data Transformation

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\naiks\Downloads\data2.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# # Sort By Values

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(["Year","IMDb"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(["Year","IMDb"],ascending=[True,False])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1=df.sort_values("Year")
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       2          Aamir Khan                    Dangal  2016
# 1       1         Salman Khan           Tiger Zinda Hai  2017
# 2      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 3       4       Ranveer Singh                 Padmaavat  2018
# 4       5  Ayushmann Khurrana                 Andhadhun  2018
# 5       6       Rajkummar Rao                     Stree  2018
# 6       7      Hrithik Roshan                       War  2019
# 7       8        Akshay Kumar                Good Newwz  2019
# 8      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 9       3       Ranbir Kapoor                Brahmastra  2022
# 10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11      0      Shah Rukh Khan                   Pathaan  2023
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1            Action                   565   6.0
# ...

# %%
df1.reset_index(drop=True,inplace=True) #inplace -  to modify the data to new

# %%
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 5        Rajkummar Rao                     Stree  2018    Horror Comedy
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2=df.sort_index()  # get the original dataset
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# # Ranking

# %%
df2["Rank"]=df2["IMDb"].rank()
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2["Rank"]=df2["IMDb"].rank(ascending=False)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2["Rank"]=df2["IMDb"].rank(ascending=False,method="dense")
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2.sort_values("Rank")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
#
# ...

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# # Renaming

# %%
df.rename(columns={"Actor":"Hero","BoxOffice(INR Crore)":"Collection"},inplace=True)

# %%
df
# Out:
#                   Hero                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     Collection  IMDb
# ...

# %%
df.rename(index={0:"Row1"})
# Out:
#                     Hero                      Film  Year            Genre  \
# Row1      Shah Rukh Khan                   Pathaan  2023           Action
# 1            Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 5        Rajkummar Rao                     Stree  2018    Horror Comedy
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.columns=["Hero","Movie","Year","Genre","Collection","Rating"]

# %%
df1
# Out:
#                   Hero                     Movie  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 5        Rajkummar Rao                     Stree  2018    Horror Comedy
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     Collection  Rating
# ...

# %%
df1=df1[["Movie","Year","Hero","Collection","Rating","Genre"]]
df1
# Out:
#                        Movie  Year                Hero  Collection  Rating  \
# 0                     Dangal  2016          Aamir Khan        2024     8.4
# 1            Tiger Zinda Hai  2017         Salman Khan         565     6.0
# 2      Badrinath Ki Dulhania  2017        Varun Dhawan         201     6.1
# 3                  Padmaavat  2018       Ranveer Singh         585     7.0
# 4                  Andhadhun  2018  Ayushmann Khurrana         111     8.3
# 5                      Stree  2018       Rajkummar Rao         180     7.5
# 6                        War  2019      Hrithik Roshan         475     6.5
# 7                 Good Newwz  2019        Akshay Kumar         318     7.0
# 8   Uri: The Surgical Strike  2019       Vicky Kaushal         342     8.2
# 9                 Brahmastra  2022       Ranbir Kapoor         431     5.6
# 10         Bhool Bhulaiyaa 2  2022       Kartik Aaryan         266     5.9
# ...
