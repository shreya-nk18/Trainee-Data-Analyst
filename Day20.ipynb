# %% [markdown]
# # Library - A collection of reusable code components that programmers can use to perform specific task.

# %% [markdown]
# # Python array creation

# %%
import array
a=array.array('i',[1,5,13,12,41])  #homogeneous data.we must supply data type at time of python
a
# Out:
# array('i', [1, 5, 13, 12, 41])

# %%
print(*a)  #if you want to extract the data only,you should print*
# Out:
# 1 5 13 12 41

# %% [markdown]
# # Extraction of elements via indexing

# %%
a[0]
a[1]
a[2]
# Out:
# 13

# %%
a[3]
# Out:
# 12

# %%
a[-1]
# Out:
# 41

# %%
a[-2]
# Out:
# 12

# %%
a[-3]
# Out:
# 13

# %%
for e in a:
    print(e)
# Out:
# 1
# 5
# 13
# 12
# 41

# %% [markdown]
# # Insertion of data in python

# %%
a.insert(1,100)
print(*a)
# Out:
# 1 100 13 12

# %%
a.append(500)
a
# Out:
# array('i', [1, 100, 13, 12, 500])

# %%
print(*a)
# Out:
# 1 100 13 12 500

# %%
del a[-1]

# %%
print(*a)
# Out:
# 1 100 13 12

# %%
a.pop()
# Out:
# 12

# %%
a.pop(1)
print(*a)
# Out:
# 1 13

# %% [markdown]
# # Creation of numpy array

# %%
import numpy as np
a1=np.array([10,20,30,40,50])
print(a1)
print(*a1)
# Out:
# [10 20 30 40 50]
# 10 20 30 40 50

# %%
print(a1.ndim)
# Out:
# 1

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a1=np.array(34)  #0 dimension array
print(a1)
print(a1.ndim)
# Out:
# 34
# 0
